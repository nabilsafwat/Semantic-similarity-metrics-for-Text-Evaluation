# %%
# !python --version
# Out:
# Python 3.9.16

# %%
original = ['Food security and sustainability: Exploring Japanese youth participation in agriculture',
'Canada\'s oil sands industry from a sustainability perspective',
'Perspectives on sustainability in humanitarian supply chains',
'Student Learning on Sustainable Development Goals through Interactive Lectures and Fieldwork in Rural Communities: Grounded Theory Approach',
'Innovation: A modering factor the effectiveness of diversification strategies on the sustainability of hospital farms',
'Building A Comprehensive Conceptual Framework for Material Selection in Terms of Sustainability in The Construction Preliminary Design Phase',
'A study of quality assessment in higher education within the context of sustainable development: A case study from Czech Republic',
'Towards sustainability in the port sector: The role of intermediation in transition work',
'Events and sustainability: why making events more sustainable is not enough',
'Local and distributed manufacturing during the COVID-19 pandemic: Is crisis a window of opportunity for sustainable development in the Global South?',
'Efficiency and sustainability analysis of the repair and maintenance operations of uns m11917 magnesium alloy parts of the aeronautical industry made by intermittent facing',
'Association rule mining tourist-attractive destinations for the sustainable development of a large tourism area in Hokkaido using Wi-Fi tracking data',
'Using the Flipped Classroom to Promote Learner Engagement for the Sustainable Development of Language Skills: A Mixed-Methods Study',
'Social leveraging of the 2010 Olympic Games: sustainability in a City of Vancouver initiative',
'Nature of the wind, the culture of the landscape: Toward an energy sustainability project in catalonia',
'Universities as potential actors for sustainable development',
'Applying carbon footprint method possibilities to the sustainable development of sports tourism',
'Effects of taxation on social innovation and implications for achieving sustainable development goals in developing countries: A literature review',
'Reprocessed Materials Used in Rotationally Moulded Sandwich Structures for Enhancing Environmental Sustainability: Low-Velocity Impact and Flexure-after-Impact Responses',
'Assessing the degree of sustainability integration in Canadian public sector procurement',
'Livestock breeding for sustainability to mitigate global warming, with the emphasis on developing countries',
'Enterprise location choice and regional sustainable development based on the theory of stable matching',
'Monitoring of efficiency of Russian agricultural enterprises functioning and reserves for their sustainable development',
'Modifications to ART service delivery models by health facilities in Uganda in promotion of intervention sustainability: A mixed methods study',
'Increasing the sustainability of alkali-activated binders: The use of sugar cane straw ash',
'Digitalization: The Engine of Sustainability in the Energy Industry',
'Drivers for universities: contribution to the sustainable development goals: An analysis of Spanish public universities',
'US biopharmaceutical companies\' stock market reaction to the COVID-19 pandemic. Understanding the concept of the paradoxical spiral from a sustainability perspective',
'The contemporary illusion: population growth and sustainability',
'Sustainability claim, environmental misconduct and perceived hypocrisy in luxury branding',
'Migration and justice in the era of sustainable development goals: a conceptual framework',
'An Empirical Analysis of Russian Regions: Debt Sustainability',
'Contribution to the sustainability challenges of the food-delivery sector: Finding from the deliveroo italy case study',
'Using publicized information to determine the sustainable development of 3-PL companies',
'Debt projections and fiscal sustainability with feedback effects',
'A study on the sustainable development of water, energy, and food in China',
'Sustainable development of microalgal biotechnology in coastal zone for aquaculture and food',
'Problems and social policy priorities sustainable development of rural territories',
'Public debt frontier: A python toolkit for analyzing public debt sustainability',
'Can business-oriented managers be effective leaders for corporate sustainability? A study of integrative and instrumental logics',
'The pharmaceutical industry and the sustainability of healthcare systems in developed countries and in Latin America',
'The role of organizational capabilities in attaining corporate sustainability practices and economic performance: Evidence from Italian wine industry',
'The impossible sustainability of the bay of brest? Fifty years of ecosystem changes, interdisciplinary knowledge construction and key questions at the science-policy-community interface',
'The impact of the COVID-19 pandemic outbreak on the sustainable development of the Turkish banking sector',
'Environmental Exploration of Ultra-Dense Nanobubbles: Rethinking Sustainability',
'Sustainability reporting: An approach to get the right mix of theory and practicality for local actors',
'Belowground and Aboveground Sustainability: Historical Management Change in a Mediterranean Agroecosystem',
'Sustainability assessment in higher education institutions',
'Socio-problematization of green chemistry: Enriching systems thinking and social sustainability by education',
'A grey forecasting approach for the sustainability performance of logistics companies',
'Mapping sustainability initiatives in higher education institutions in Latin America',
'What is blue growth? The semantics of â€œSustainable Developmentâ€ of marine environments',
'Self-sustainability in nano unmanned aerial vehicles: A blimp case study',
'Needle and Stick save the world: Sustainable development and the universal child',
'Farmer field schools: A tool empowering sustainability and food security in peasant farming systems in the nicaraguan highlands',
'Sound Design of Guqin Culture: Interactive Art Promotes the Sustainable Development of Traditional Culture',
'Developing an index of sustainable development goals for local governments: the case of Gyeonggi province in korea',
'Agriculture in urban ecosystems: A step to cities sustainability',
'E-commerce sustainability: The case of Pinduoduo in China',
'How to maintain the sustainable development of a business platform: A case study of Pinduoduo Social Commerce Platform in China',
'Becoming child and sustainability: the kindergarten teacher as agency mobiliser for sustainability through keeping the concept of the child in play',
'Assessment of the sustainability of wild rocketproduction: Application of a multi-criteria method to different farming systems in the province of Udine',
'Factors affecting adoption, implementation fidelity, and sustainability of the Redesigned Community Health Fund in Tanzania: A mixed methods protocol for process evaluation in the Dodoma region',
'Drawing the line between sustainable and unsustainable fish: product differentiation that supports sustainable development through trade measures',
'The Application of Risk Analysis To The Project Appraisal Of Stingless Bee Farming In Malaysia For Sustainability',
'Orbital Debris Threat for Space Sustainability and Way Forward',
'Financial and economic feasibility of bio-digesters for rural residential demand-side management and sustainable development',
'Increasing energy-saving actions in low income households to achieve sustainability',
'Cotton and surgical masks: what ecological factors are relevant for their sustainability?',
'Availability of nicotine replacement therapy in substance use disorder treatment: Longitudinal patterns of adoption, sustainability, and discontinuation',
'Putting resilient sustainability into strategy decisions case studies',
'A comparison of electricity generation system sustainability among G20 countries',
'Taxi downsizing: A new approach to efficiency and sustainability in the taxi industry',
'Analysis of OpenStreetMap Data Quality for Selected Counties in Poland in Terms of Sustainable Development',
'Analysis of scale factors on China\'s sustainable development efficiency based on three-stage DEA and a double threshold test']

# %%
len(original)
# Out:
# 75

# %%
## SEMANTIC SIMILARITY

## Knowledge based similarity - 1. Sematch (uses wordnet ontology) (using wup, res and lin* probably)
##                              2. Conceptnet ontology (implementation on gensim) (Maybe needs conversion to w2vec format, will check this later)
## Statistical based similarity - Vector representations, based on features (Word2vec, FastText Explored) (GloVe conversion has issues)
## Language model based similarity - Using Transformers, RoBERTa is available. 
## NLG Evaluation metrics - BLEU and ROUGE 

## Copy paste the keywords and preds from 'computations for thesis' for metrics.

# %%
## What should keyword format be for each metric:

## Sematch(wup, res, lin): list of lists
## word2vec, fasttext: list of lists
## transformer based: list of strings
## bleu, rouge: list of strings

# %%
## Libraries
# !pip install rouge
# !pip install transformers
# !pip install sentence-transformers
# !pip install nltk
# !pip install gensim
# !pip install sematch
# !pip install pytorch
import pickle
import re
import pandas as pd
import numpy as np
import gensim
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
import pprint
from rouge import Rouge
from gensim.parsing.preprocessing import remove_stopwords
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import corpus_bleu
from rouge import Rouge
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sentence_transformers import SentenceTransformer, util
from gensim.models import KeyedVectors
from gensim.models import word2vec
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.test.utils import datapath, get_tmpfile

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 92.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 105.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 24.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 307.5 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 58.1 MB/s eta 0:00:00
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=a3b99ce1ab116f7695cf5e19a5db3adcd4a13b7d134fa49a3755931bad78bdea
# ...

# %%
## Language model based similarity
model = SentenceTransformer('stsb-roberta-large')

# %%
# For this, I will convert the list into a string just like rouge. #Make lower() first
t5 = [['Youth and food sustainability: A qualitative study in Japan',
  'Youth involvement in food sustainability in Japan: A phenomenological study',
  'The youth and agriculture in Japan: A phenomenological approach for the sustainability of food supply'],
 ['The impact of oil sands development on economic sustainability',
  'Three pillars of sustainability: A study of the oil sands industry in Canada',
  'Sustainability of oil sands development in Canada'],
 ['Insights into the contextual context and expectations of humanitarian organisations on sustainability',
  'Sustainable development based on societal expectations of humanitarian organisations',
  'Managing social expectations and sustainability: The case of humanitarian organisations'],
 ['A study of student learning theory and perspectives on sustainable development goals in rural Japan',
  'Education for sustainability goals in rural Japanese universities: Study on the learning and attitude of rural university students',
  'The Effectiveness of Learning and Halting Ideas in a SDG Education for Sustainable Development in Rural Japanese Universities: Findings from a Grounding Theory Approach'],
 ['Innovation and sustainability in hospitality firms',
  'The moderating effect of innovative diversification strategies on sustainability of hospitality firms: A case study of Nigerian four-star hotels',
  'Diversification strategies and hospitality firms sustainability in Nigeria'],
 ['Materials selection in construction projects for sustainability in the preliminary design phase',
  'Material selection and sustainable development in the preliminary design phase of construction projects',
  'Preliminary design for sustainable development of construction projects'],
 ['Management systems for sustainability-building: An application of excellence models to the education system',
  'Quality management systems at universities and sustainable development',
  'Quality management systems at universities in the context of sustainable development: A case study'],
 ['Intermediation and transition: The role of port authorities in shaping a sustainable development agenda',
  'Port intermediation, energy sustainability and a critical work question',
  'Managing energy and port energy and the sustainability of port intermediation-transition work from transport to energy'],
 ['Events and sustainability: a new perspective',
  'Event studies and sustainability: A conversational synthesis',
  'Event Studies and Sustainability: A Synopsis of the Papers'],
 ['Developing distributed manufacturing solutions for sustainability transitions: A longitudinal case study of a non-governmental organization',
  'Decentralized Manufacturing Solutions in the Global South during the COVID-19 Pandemic: A Perspective on the Process of Sustainability Transitions',
  'Distributed manufacturing: Impacts of sustainability transitions: the COVID-19 pandemic'],
 ['Sustainability in the sustainability of intermittent facing operations in the aerospace industry',
  'Efficiency, sustainability and efficiency in airframe repair operations: The application of intermittent facing on magnesium alloy rod',
  'Interruption of mechanical fixing operations in the aerospace industry: a study of efficiency and sustainability'],
 ["Monitoring tourist's traveling behavior using wifi-enabled data acquisition for sustainable development of tourism in osaka, Japan",
  'Using Wi-Fi Wireless Scanner to Track Traveling Behavior in Tourism Area for Sustainable Development in Japan',
  "An application of WiFi-enabled survey to observe tourists' traveling behavior in the hkaido region"],
 ['An empirical study on the benefits of a flipped college English listening and speaking class for improve behavioural and emotional and social engagement of English as a foreign language learners',
  'Impact of flipped classrooms on English as a Foreign Language Learners’ Engagement: A Mixed-Methods Research Approach',
  'Using the flipped English Listening and Speaking class in college English listening and speaking classes for enhance sustainability'],
 ['Increasing involvement of host governments in the sustainability of community and sports mega-events: A Vancouver case study',
  'Governing with sustainability: Social leverage of the Vancouver 2014 Olympic Greenest City Initiative',
  "Social leverage, sustainability, and the future of the city: A case study of the city's Greenest City initiative"],
 ['A critical reflection on energy and landscape: Guidelines for an installation in Catalonia',
  'How to be sustainable: Towards a sustainability landscape: A proposal for Catalonia',
  'Renewable energy and landscape, ecological sustainability and sustainability'],
 ['Innovation and sustainability in universities of Germany',
  'Educating future decision makers: Using sustainability theory and applied to the German universities',
  'A global view of the importance of universities as a leading model for sustainable development'],
 ['Carbon Footprint Method to Evaluate the Impact of Transportation on Environmental Sustainability',
  'Carbon footprint and sustainable development in the context of global warming',
  'Carbon Footprint Modeling for predicting the environmental sustainability in tourism'],
 ['Taxation, social innovation, and sustainable development goals: An analysis',
  'Taxation as a barrier to economic growth: Implications for sustainable development goals',
  'Taxation and social innovation in the pursuit of sustainable development goals: Case studies of developing countries'],
 ['Sustainability and social sustainability for rotationally moulded sandwich structures',
  'Reprocessing non-used, scrap, and waste purge materials for sandwich structures to reduce their environmental impact - A feasibility study in the rotational moulding industry',
  'Recycling in Skin-Foam-Skin Sandwich Structures: An Affordable Alternative to the Use of Virgin Polymers and Environmental Resilience'],
 ['The state of sustainability integration in public procurement',
  'Sustainability Integration in Canadian government procurement',
  'Sustainability integration into government procurements: a comparison study'],
 ['Measurement of sustainability of livestock production in developing countries: Role of ecological values and reproductive traits',
  'Measuring and quantifying the sustainability of livestock production in developing countries',
  'The use of adaptive indicators in the management of sustainable development of livestock from agricultural to natural resources'],
 ['Achieving sustainable development of regional economies by an optimal match between enterprise location selection and local government investment attraction',
  'Investing in the sustainability of local economies based on enterprise location selection',
  "Enterprise-Local Governments-Enterprises and Local Governments' Aspects of the Sustainability of Chinese Industry Transfer: An Approach"],
 ['Conservation and Management of Agricultural Production: A Study on the Economic Efficiency of Agriculture',
  'A study on an efficiency measure of agricultural enterprises in a developing country',
  'Evaluating the economic efficiency of agricultural enterprises in the Russian agrarian sector using reserves'],
 ['MODIFICATIONS TO ART SERVICES IN MAIN STRATEGY-SUSTAINABLE NORD ALIGNMENTS  TOXIC ART WORKS IN RUNA, ENGLAND',
  'Pre-clinical simulation in Uganda to evaluate and respond to HIV treatment scale-up interventions',
  'The role of the multi-district health care system: Implications for the sustainability of ART delivery programs in resource-limited settings'],
 ['Improving the structural sustainability of alkali-activated binders using sugar cane straw as solid precursor',
  'An analysis of the use of bio-chemically active sugar cane straw in alkali-activated binders',
  'Activating BFS/SCSA on alkali-activated binders for building construction study: Environmental and mechanical properties'],
 ['Analyzing the scientific literature on the sustainability of digitalization in the energy sector',
  'The Sustainability of Digitalization in the Energy Sector in Italy: A bibliometric analysis',
  'Digitalization for Energy Sustainability'],
 ['The role of universities in the implementation of the sustainable development goals [Las universidades a los de las sostenibilidades de todo el mundial]',
  'University Policies for the Inclusion of the Sustainable Development Goals',
  'Inclusion of sustainable development goals and processes in university management: Approaches for supporting the integration of actors and stakeholders'],
 ['An independent stock market analysis of two biopharmaceutical companies developing messenger RNA vaccines against COVID-19',
  'The market reaction of two biopharmaceutical companies to the COVID-19 pandemic: A case of biopharmaceutical companies',
  'Market sentiment in the USA Biopharmaceutical Sector to promote a sustainability-oriented biopharmaceutical portfolio'],
 ['Global population projections and sustainability—An overview',
  'Achieving demographic sustainability: a theory and its application in the German case',
  'Population Future and Sustainability: the Impossibles of a Population Growth'],
 ['Brand misconduct and sustainability claims: Consumer’s perceptions and reaction',
  'Brand hypocrisy and brand distance: the scepticism to sustainability',
  'Rethinking consumer attitudes towards brand misconduct and sustainability claims'],
 ['Debates on migration and sustainable development: how can we make a more sustainable migration?',
  'How to integrate sustainability in migration in the development process?',
  "Migratory sustainability and economic development: An academic analysis of a country's strategic goals"],
 ['Deleveraging and debt sustainability in Russian regions',
  'Debt sustainability of the Russian economy: Measurement of Euclidean distance budget constraints',
  'Economic, economic, environmental, and sustainability of government borrowing in Russia'],
 ['Promoting sustainable development of food delivery sector by electro-mobility',
  'Electro-mobility as an obstacle to sustainability in the food delivery sector',
  'Electro-mobility as a key enabling factor for the sustainability of the food delivery sector in Italy'],
 ['Mission statement review: A holistic approach for sustainability development',
  'Sustainability development in public information: A research on the logistics industry',
  'Sustainability issues in business: Strategic strategy for public information based on global 3-PL companies'],
 ['Fiscal sustainability of fiscal policy - A mechanism involving feedback effects',
  'A model integrating the feedback effect and sustainability feedbacks of public spending on fiscal policy',
  'Fiscal sustainability and its impact on public debt: A model based on a number of feedback effects'],
 ['Water-energy-food system and sustainable development: An application of system dynamics model for China',
  'System Dynamics, Water-Energy-Food Internal System, and Sustainable Development in China',
  'Sustainability scenario simulation in the water-energy-food system simulation for China: A two-child policy and trade friction'],
 ['Research and Development for “Green Gold” Microalga-Derivate Systems: A Case study in the Mediterranean Pacific',
  'Ecological modelling of microalgal biotechnology in the coastal areas',
  'Microalga development under cradle-to-grave scalability and commercialization in a coastal area: An evolutionary study of biotechnologies'],
 ['Sustainable development of rural areas in the republic of Komi',
  'Sustainable development of the republic of komi',
  'The lagging economy in the rural areas: Is sustainable development possible?'],
 ['A visual indicator for debt sustainability analysis using dynamic general equilibrium models',
  'Structural sustainability assessment of public debt using dynamic general equilibrium models',
  'Sustainable debt sustainability analysis using dynamic general equilibrium models'],
 ["Management's views on corporate sustainability? A qualitative review",
  "Congruence of organizational sustainabilitylogics and managers' CS positions",
  'Organizing organization CS logic: Managers’ views of corporate sustainability'],
 ['Sustainability in the use of generic and biosimilar medications',
  'Environmental sustainability in Latin America: A focus on the optimisation of bioequivalence between generic and biosimilar branded medications',
  'Utilization of bioequivalence products to support sustainability in global health systems'],
 ['The role of organizational capabilities in corporate sustainability practices and organizational performance: A dynamic resource-based perspective',
  'Three organizational capabilities for implementing sustainable development and related economic performance: A dynamic resource-based perspective',
  'A sustainable corporate management model for firms: Exploring the role of organizational capability in the implementation of proactive business practices and their economic performance'],
 ['Ecological transformations in the Bay of Brest—for sustainable development',
  'Analyzing sustainability challenges in the Bay of Brest: a study with a case study',
  'Environmental sustainability: The Bay of Brest ecosystem shifts over the past 50 years'],
 ['Analysis of the development of the banking sector by looking at the correlation between the COVID-19 and the Turkey pandemic period',
  'Expansion of banking sector in Turkey: The role of COVID-19 and its sustainability',
  'The effect of COVID-19 on banking development in Turkey in the period of COVID-19 — A comparative perspective'],
 ['Nanobubbles and sustainability in agriculture',
  'Nano-bubble boosting, enhancing sustainability of agriculture: Applications for industrial agriculture',
  'Sustainability of nanobubbles by using nano-bubbles'],
 ['Sustainability reporting tools for local government: collaborative approaches to building a sustainable reporting tool',
  'Collaborative reporting tools for communities: the case of the UK',
  'Understanding where a community is on the path to sustainability? A collaborative approach to development of reporting tools'],
 ['Understanding the agricultural practices linked to the maintenance of soil fertility in a semi-arid Mediterranean village: A sociometabolic perspective',
  'The sustainability assessment of the Mediterranean crop system and the sustainable development of the agriculture system[Análise desde la sustentabilidade de la biofauna y desarrollo de la producción)',
  'The sociometabolic relationship between agricultural practices and the assessment of soil sustainability'],
 ['Sustainability assessment in higher education institutions',
  'The evaluation of sustainability implementation dimensions at higher education institutions',
  'Sustainability assessment and assessment: An international perspective in higher education institutions'],
 ['Challenges to systems thinking: Green chemistry and social sustainability',
  'Systemic thinking for the social dimension of sustainability. An analysis of green chemistry',
  'A systemic approach to sustainable development in green chemistry'],
 ["Global logistics operations' sustainability-related efficiency averaging with grey forecasting academe: A study",
  'The role of grey forecasting in the decision-making process on organizational performance and environmental sustainability',
  'Utilization of the DEA Model for Forecasting Sustainable Development of Logistics Companies: A Case Study of Applied Systems Inc.'],
 ['Sustainability initiatives in Latin American higher education institutions: An empirical analysis',
  'The Status of Sustainability Initiatives in Latin America: Case Studies from the Universidades Latinas',
  'Evaluation of sustainability initiatives in higher education institutions: Case of Latin America'],
 ['Blue growth and sustainable development: Working together?',
  'The context of blue growth and sustainable development',
  'Blue growth and sustainable development: A bidirectional and bidirectional research guide'],
 ['Bilip platform technology for sustainable development: A novel energy-constrained drone',
  'Nano-sized nano unmanned aircraft: A novel approach to sustainability',
  'Bio-energy efficiency versus low energy sustainability in the nano-sized blimp'],
 ['Sustainable development and childhood: A theoretical account of knowledge',
  'Sustainable development and childhood',
  'Sustainability and Childhood: Sustainability in the Global System'],
 ['A review of the role of farmer field schools in improving sustainability of peasant-farming systems',
  'Farmer field schools in the Nicaraguan highlands: A social impact assessment framework to assess sustainability',
  'An empirical assessment of the sustainability of peasant-farming systems using farmers field schools in Nicaragua'],
 ['Sustainable development of Guqin culture through sound interactive communication',
  'The interactive dissemination of traditional cultural in public space for sustainable development of Guqin culture through the use of sound',
  'Bringing the legacy of tradition to the public through sound: A new approach to develop Guqin cultural heritage sustainability'],
 ['Sustainable development goals and localization in Gyeonggi Province of South Korea: Towards the comparative evaluation of the indicators',
  'Sustainable development goals for local government in Gyeonggi Province, South Korea: Glocal mainstreaming and localization of SDGs',
  'Sustainable development Goals indicators of Gyeonggi Province, South Korea'],
 ['Urban agriculture and the urban ecosystem: An empirical investigation',
  'The regenerative mechanism of the urban agriculture program to foster sustainability of urban agriculture in the city of Rio de Janeiro',
  'Urban agriculture and sustainable development: A case study of a city in the beira de janeiro metropolitan region'],
 ['A broader market-share analysis of the omni-channel shopping ecosystem in China using e-commerce platforms',
  'Globalization through the omni-channel platform ecosystem: A promising new e-commerce platform for China',
  'Suggested use-case of web-based shopping platforms in China: A e-commerce success of the three-year-old Pinduoduo'],
 ['How Pinduoduo’s platform business model changes with time: A study on China',
  'Analysis of the role of platform providers in the sustainability of the platform',
  'Platform business model as key enabler for sustainable development of ecommerce platform: A case study of Pinduoduo'],
 ['The Kindergarten Teacher and the Agency Mobilizer for Sustainability',
  'The role of the kindergarten teacher as a agency mobilizer for sustainability',
  "Education and sustainability in kindergarten teachers' roles"],
 ['Multifunctionality assessment and sustainability assessment of different cultivation methods',
  'Multifunctionality of different farming systems: A multi-criteria assessment method',
  'Multi-criteria analysis to assess a variety of organic and conventional farming methods in relation to their multifunctional effects'],
 ['Uncovering processes and failures in the implementation of micro health insurance in Tanzania: A process evaluation protocol',
  'Process evaluation of the redesigned community health fund program in Dodoma region of Tanzania',
  'Evaluation of process evaluation of a Community Health Fund Program in Tanzania to address low enrollment'],
 ['Do sustainable and unsustainable fish differentiate? A study in Switzerland',
  'The differentiation of sustainable and unsustainable fish in Switzerland',
  'Sustainability in fish trade and sales: a study of unsustainable fish in Switzerland'],
 ['Financial projections and risk factors to optimize the sustainability of stingless bee farming in Malaysia',
  'Sustainability projections of stingless bee farming project in Malaysia',
  'Sustainability and viability of stingless bees: Assessing the projected sustainability of sustainable development'],
 ['Space debris and the current situation in the field of space technology security and sustainability',
  'The space debris threat and its implementation--the case of Iceland',
  'The orbital/space debris crisis, the challenges of security, security and sustainability.'],
 ['Sustainability of biogas digesters in rural villages: Implications for sustainable development',
  'Sustainability of biogas production for energy demands at the rural household or village scale',
  'The financial and economic feasibility of biogas production to meet energy demands at the household or village scale in the Eastern Cape, South Africa'],
 ['Energy sustainability behaviour change for Australian low-income households',
  'An energy-saving behaviour change program for low income households in the south-west of Australia for energy sustainability',
  'Energy saving behaviour change as a means to bridge sustainability goals in low-income households in Australia'],
 ['Environmental sustainability assessment of facial masks using a Lifecycle Assessment',
  'The ecological sustainability of textile masks in facemasks: A life cycle analysis for plastic surgery',
  'Sustainable development of facemasks under the conditions of environmental sustainability'],
 ['Organizational characteristics and NRT availability in substance use disorder treatment programs: A longitudinal study',
  'Organizational characteristics and the adoption of nicotine replacement therapy in substance use disorders in the management of substance use disorders treatment programs',
  'The importance of nicotine replacement therapy for recovery of substance use disorder treatment: The role of organizational covariates'],
 ['Resilience and sustainability in strategic decision-support: The case of industrial companies',
  'SuReSDS - The resilient strategic decision-support approach to sustainability and resilience',
  'New approaches to strategic sustainability and resilience: the case of sustainable resilient strategic decision support'],
 ['Assessing energy sustainability through a data-envelopment approach',
  'An integrated sustainability assessment method for electricity generation systems',
  'Energy sustainability assessment index systems'],
 ['Taxi taxi policy reduction and sustainable development: Using hatchback cars with two rows of seats in China',
  'Taxis sustainability in China: A small hatchback car with two rows of seats',
  'Sustainability of taxis as a way to cut costs'],
 ['OpenStreetMap, OpenStreetMap, or any other Open Data Application for Sustainable Development? The Case of Kazakhstan',
  'Open data for sustainable development goalsindicators: A systematic review',
  'OpenStreetMap: A Statistical Evaluation of the Spatial Data Quality Elements and Sustainable Development Indicators'],
 ['Sustainability assessment and analysis of 40 provinces and cities in China using Super-Slack',
  'Sustainable development efficiency: A three-stage data envelope analysis approach based on super-slack-based data analysis',
  "A three-stage data envelope analysis method for studying China's sustainable development efficiency"]]

t5_sen =  [item[0] for item in t5]
t5_lower_sen = [x.lower() for x in t5_sen]
t5_tok_sen = [word_tokenize(i) for i in t5_lower_sen] 


original = ['Food security and sustainability: Exploring Japanese youth participation in agriculture',
'Canada\'s oil sands industry from a sustainability perspective',
'Perspectives on sustainability in humanitarian supply chains',
'Student Learning on Sustainable Development Goals through Interactive Lectures and Fieldwork in Rural Communities: Grounded Theory Approach',
'Innovation: A modering factor the effectiveness of diversification strategies on the sustainability of hospital farms',
'Building A Comprehensive Conceptual Framework for Material Selection in Terms of Sustainability in The Construction Preliminary Design Phase',
'A study of quality assessment in higher education within the context of sustainable development: A case study from Czech Republic',
'Towards sustainability in the port sector: The role of intermediation in transition work',
'Events and sustainability: why making events more sustainable is not enough',
'Local and distributed manufacturing during the COVID-19 pandemic: Is crisis a window of opportunity for sustainable development in the Global South?',
'Efficiency and sustainability analysis of the repair and maintenance operations of uns m11917 magnesium alloy parts of the aeronautical industry made by intermittent facing',
'Association rule mining tourist-attractive destinations for the sustainable development of a large tourism area in Hokkaido using Wi-Fi tracking data',
'Using the Flipped Classroom to Promote Learner Engagement for the Sustainable Development of Language Skills: A Mixed-Methods Study',
'Social leveraging of the 2010 Olympic Games: sustainability in a City of Vancouver initiative',
'Nature of the wind, the culture of the landscape: Toward an energy sustainability project in catalonia',
'Universities as potential actors for sustainable development',
'Applying carbon footprint method possibilities to the sustainable development of sports tourism',
'Effects of taxation on social innovation and implications for achieving sustainable development goals in developing countries: A literature review',
'Reprocessed Materials Used in Rotationally Moulded Sandwich Structures for Enhancing Environmental Sustainability: Low-Velocity Impact and Flexure-after-Impact Responses',
'Assessing the degree of sustainability integration in Canadian public sector procurement',
'Livestock breeding for sustainability to mitigate global warming, with the emphasis on developing countries',
'Enterprise location choice and regional sustainable development based on the theory of stable matching',
'Monitoring of efficiency of Russian agricultural enterprises functioning and reserves for their sustainable development',
'Modifications to ART service delivery models by health facilities in Uganda in promotion of intervention sustainability: A mixed methods study',
'Increasing the sustainability of alkali-activated binders: The use of sugar cane straw ash',
'Digitalization: The Engine of Sustainability in the Energy Industry',
'Drivers for universities: contribution to the sustainable development goals: An analysis of Spanish public universities',
'US biopharmaceutical companies\' stock market reaction to the COVID-19 pandemic. Understanding the concept of the paradoxical spiral from a sustainability perspective',
'The contemporary illusion: population growth and sustainability',
'Sustainability claim, environmental misconduct and perceived hypocrisy in luxury branding',
'Migration and justice in the era of sustainable development goals: a conceptual framework',
'An Empirical Analysis of Russian Regions: Debt Sustainability',
'Contribution to the sustainability challenges of the food-delivery sector: Finding from the deliveroo italy case study',
'Using publicized information to determine the sustainable development of 3-PL companies',
'Debt projections and fiscal sustainability with feedback effects',
'A study on the sustainable development of water, energy, and food in China',
'Sustainable development of microalgal biotechnology in coastal zone for aquaculture and food',
'Problems and social policy priorities sustainable development of rural territories',
'Public debt frontier: A python toolkit for analyzing public debt sustainability',
'Can business-oriented managers be effective leaders for corporate sustainability? A study of integrative and instrumental logics',
'The pharmaceutical industry and the sustainability of healthcare systems in developed countries and in Latin America',
'The role of organizational capabilities in attaining corporate sustainability practices and economic performance: Evidence from Italian wine industry',
'The impossible sustainability of the bay of brest? Fifty years of ecosystem changes, interdisciplinary knowledge construction and key questions at the science-policy-community interface',
'The impact of the COVID-19 pandemic outbreak on the sustainable development of the Turkish banking sector',
'Environmental Exploration of Ultra-Dense Nanobubbles: Rethinking Sustainability',
'Sustainability reporting: An approach to get the right mix of theory and practicality for local actors',
'Belowground and Aboveground Sustainability: Historical Management Change in a Mediterranean Agroecosystem',
'Sustainability assessment in higher education institutions',
'Socio-problematization of green chemistry: Enriching systems thinking and social sustainability by education',
'A grey forecasting approach for the sustainability performance of logistics companies',
'Mapping sustainability initiatives in higher education institutions in Latin America',
'What is blue growth? The semantics of â€œSustainable Developmentâ€ of marine environments',
'Self-sustainability in nano unmanned aerial vehicles: A blimp case study',
'Needle and Stick save the world: Sustainable development and the universal child',
'Farmer field schools: A tool empowering sustainability and food security in peasant farming systems in the nicaraguan highlands',
'Sound Design of Guqin Culture: Interactive Art Promotes the Sustainable Development of Traditional Culture',
'Developing an index of sustainable development goals for local governments: the case of Gyeonggi province in korea',
'Agriculture in urban ecosystems: A step to cities sustainability',
'E-commerce sustainability: The case of Pinduoduo in China',
'How to maintain the sustainable development of a business platform: A case study of Pinduoduo Social Commerce Platform in China',
'Becoming child and sustainability: the kindergarten teacher as agency mobiliser for sustainability through keeping the concept of the child in play',
'Assessment of the sustainability of wild rocketproduction: Application of a multi-criteria method to different farming systems in the province of Udine',
'Factors affecting adoption, implementation fidelity, and sustainability of the Redesigned Community Health Fund in Tanzania: A mixed methods protocol for process evaluation in the Dodoma region',
'Drawing the line between sustainable and unsustainable fish: product differentiation that supports sustainable development through trade measures',
'The Application of Risk Analysis To The Project Appraisal Of Stingless Bee Farming In Malaysia For Sustainability',
'Orbital Debris Threat for Space Sustainability and Way Forward',
'Financial and economic feasibility of bio-digesters for rural residential demand-side management and sustainable development',
'Increasing energy-saving actions in low income households to achieve sustainability',
'Cotton and surgical masks: what ecological factors are relevant for their sustainability?',
'Availability of nicotine replacement therapy in substance use disorder treatment: Longitudinal patterns of adoption, sustainability, and discontinuation',
'Putting resilient sustainability into strategy decisions case studies',
'A comparison of electricity generation system sustainability among G20 countries',
'Taxi downsizing: A new approach to efficiency and sustainability in the taxi industry',
'Analysis of OpenStreetMap Data Quality for Selected Counties in Poland in Terms of Sustainable Development',
'Analysis of scale factors on China\'s sustainable development efficiency based on three-stage DEA and a double threshold test']

original_lower_sen = [x.lower() for x in original]
original_tok_sen = [word_tokenize(i) for i in original_lower_sen]

# %%
bart = [['Youth engagement in the Japanese agriculture industry: A qualitative study on sustainability of food supply',
  'Youth engagement in the Japanese agriculture industry: A study on the sustainability of food supply',
  'Youth engagement in the Japanese agriculture industry: A qualitative study on food sustainability'],
 ['Impacts of oil sands development on the economy, society and the environment as three pillars of sustainability in Canada',
  'Impacts of oil sands development on the economy, society and the environment as three pillars of sustainability',
  'The impacts of oil sands development on the economy, society and the environment as three pillars of sustainability'],
 ['Humanitarian organisations addressing sustainability from the perspective of societal and contextual expectations',
  'Humanitarian organisations addressing sustainability from the perspective of societal and contextual expectations',
  'Humanitarian organisations addressing different expectations regarding sustainability: A framework for analysing sustainability'],
 ['Evaluating the effectiveness of sustainable development goals education in rural Japanese universities using grounded theory',
  'Evaluating the effectiveness of sustainable development goals education in rural Japanese universities: A grounded theory approach',
  'Evaluating the effectiveness of sustainable development goals education in rural Japanese universities: A grounded theory approach'],
 ['Innovation as a moderating factor for the effectiveness of diversification strategies on the sustainability of hospitality firms in Nigeria',
  'Innovation as a moderating factor for the effectiveness of diversification strategies on the sustainability of hospitality firms in Nigeria',
  'Innovation as a moderating factor for the effectiveness of diversification strategies on the sustainability of hospitality firms in Nigeria'],
 ['Sustainability in the preliminary design phase of construction projects',
  'Sustainability in the preliminary design phase of construction projects',
  'Sustainability in the preliminary design phase of construction projects'],
 ['Quality management systems in higher education for sustainable development [Sistemas de administração superior en la educación superior para el desarrollo sostenible]',
  'Quality management systems in higher education for sustainable development [Sistemas de gestión superior en la educación superior para el desarrollo sostenible]',
  'Quality management systems at universities in the context of sustainable development [Sistemas de gestão de sostenibilidad en universidades]'],
 ['Intermediation and sustainability transitions in ports: How intermediation connects to transition work',
  'Intermediation in ports: How intermediation connects to sustainability transitions',
  'Intermediation in ports: How intermediation connects to sustainability transitions'],
 ['The special issue on events and sustainability: A review',
  'The special issue on events and sustainability: An exploration of interrelationships between events and sustainable development',
  'Events and sustainable development: A special issue on events'],
 ['Sustainability transitions and distributed manufacturing in the Global South: A longitudinal case study of a non-governmental organization',
  'Sustainability transitions and distributed manufacturing in the Global South: A longitudinal case study of a non-governmental organization',
  'Sustainability transitions and distributed manufacturing in the Global South: A longitudinal case study of a non-governmental organization'],
 ['Efficiency and sustainability of intermittent facing operations in maintenance operations in the aeronautical industry: A case study',
  'Efficiency and sustainability of intermittent facing operations in maintenance operations',
  'Efficiency and sustainability of intermittent facing operations in maintenance operations'],
 ["Digital Footprint Analysis for Tourism Sustainability: A Study of Tourists' Travel Behavior in a Tourism Area in Hokkaido, Japan",
  "Sustainability of tourism in hokkaido's tourism area: Using Wi-Fi scanners to track tourists' traveling behavior",
  "Sustainability of tourism in hokkaido's tourism area: An application of Wi-Fi scanners"],
 ['The impact of a flipped college English listening and speaking class on four-dimension learner engagement in a second language education course: A mixed-methods study',
  'The impact of a flipped college English listening and speaking class on four-dimension learner engagement in a second language education course: A mixed-methods study',
  'The impact of a flipped college English listening and speaking class on four-dimension learner engagement in a second language education course: A mixed-methods study'],
 ["Social leveraging for sustainable development: Vancouver's post-Olympic greenest city initiative",
  "Social leveraging for sustainable development: Vancouver's post-Olympic greenest city initiative",
  "Social leveraging for sustainability: Vancouver's post-Olympic greenest city initiative"],
 ['Wind energy and landscape: A critical reflection on the possible spatial, ethical, aesthetic effects of energy transition',
  'Wind energy and landscape: A critical reflection on the possible spatial, ethical, aesthetic effects of energy transition',
  'Wind energy and landscape: A critical reflection on the sustainability of energy transition'],
 ['Integrating sustainability into higher education curricula: A case study of a German university',
  'Integrating sustainability into higher education: A case study of the University of Tübingen',
  'Sustainable development in higher education: An approach to integrate sustainability in research, organization, and education'],
 ['The Impact of Tourism on the Environmental Sustainability of Space: A Carbon Footprint Approach',
  'The impact of tourism on the environment: A case study on the transport of tourists from their homes to their destinations and back',
  'Carbon Footprint Methodology for the Sustainability Assessment of Tourism in Space'],
 ['The effects of taxation on social innovation and its implications for the achievement of sustainable development goalsin developing countries',
  'The effects of taxation on social innovation and its implications for the achievement of sustainable development goalsin developing countries',
  'The effects of taxation on social innovation and its implications for the achievement of sustainable development goalsin developing countries'],
 ['Sustainability assessment of non-used, scrap, and waste purge materials applied to skin-foam-skin sandwich structures: A low-cost, low-impact approach',
  'Sustainability assessment of low-cost recycled non-used, scrap, and waste purge materials in skin-foam-skin sandwich structures in rotational moulding industry',
  'Sustainability assessment of non-used, scrap, and waste purge materials applied to skin-foam-skin sandwich structures: A case study in the rotational moulding industry'],
 ['Sustainability integration in Canadian government procurement: Current status and future prospects',
  'Sustainability integration in Canadian government procurement: An analysis of RFPs',
  'Sustainability integration in Canadian government procurement: An analysis of the current state and recommendations for future progress'],
 ['Adaptation of livestock to climate change and its impact on the sustainability of livestock production',
  'Evaluating the sustainability of livestock production in developing countries using proxy-indicators for adaptation',
  'Evaluation of the adaptation of livestock to climate change in developing countries: A step towards sustainable development'],
 ['Evaluation of the relationship between firms and local governments for the transfer of industries in China: A sustainable development perspective',
  'Evaluation of the relationship between firms and local governments for the transfer of industries for the sustainable development of regional economies: A case study in China',
  'Evaluation of the Sustainability of Enterprise Location Selection and Local Government Investment Attraction Based on Linguistic Evaluation Information: A Case Study in China'],
 ['Reserves and measures to improve the efficiency of agricultural enterprises for sustainable development of the Russian agrarian sector',
  'Reserves and measures to improve the efficiency of agricultural enterprises for the sustainable development of the sector',
  'Sustainable development of the Russian agrarian sector: Reserves and measures to improve the efficiency of agricultural enterprises'],
 ['Models for sustainability of antiretroviral therapy in health facilities in Uganda: A mixed methods approach',
  'Modeling the sustainability of antiretroviral therapy scale-up programs in Uganda: A mixed methods approach',
  'Modeling modifications to ART service delivery models by health facilities in Uganda to sustain and expand ART interventions over a 10-year period: A mixed methods approach'],
 ['Sustainability of blast-furnace slag-based alkali-activated binders: The influence of sugar cane straw ash',
  'Sustainability of blast-furnace slag-based alkali-activated binders using sugar cane straw ash',
  'Sustainability assessment of blast-furnace slag-based alkali-activated binders based on sugar cane straw ash'],
 ['Sustainability of digitalization in the energy sector: A bibliometric analysis of the scientific literature',
  'Sustainability of digitalization in the energy sector: A bibliometric analysis of the scientific literature',
  'Bibliometric analysis of the scientific literature on the sustainability of digitalization in the energy sector'],
 ['The role of universities in the implementation of the sustainable development goals',
  'The role of universities in achieving the sustainable development goals',
  'The role of universities in achieving the sustainable development goals: The case of the University of Oxford'],
 ['Stock market reaction of two US biopharmaceutical companies to the COVID-19 pandemic and the role of messenger RNA vaccines in the sustainability of the green economy',
  'The stock market reaction of two US biopharmaceutical companies that first developed messenger RNA vaccines against COVID-19: A step towards sustainability',
  'The stock market reaction of two US biopharmaceutical companies that first developed messenger RNA vaccines against COVID-19: Implications for the sustainability of green economy'],
 ['Population growth and sustainability: A critical analysis',
  'Population growth and sustainability: The case of the growing spots',
  'Sustainability and population growth: The case of growing spots'],
 ['Sustainability and hypocrisy: Exploring consumers’ evaluation of and reaction to the coexistence of brand misconduct and sustainability claims',
  'Sustainability claims and consumers’ reaction: The mediating role of hypocrisy',
  'Sustainability claims, hypocrisy and brand distance: Exploring consumers’ evaluation and reaction to the coexistence of brand misconduct and sustainability claims'],
 ['Sustainability in migration: The role of trade-offs',
  'Sustainability in migration: An agenda for trade-offs',
  'Sustainability in migration: A trade-offs approach'],
 ['Moderate growth of government borrowing and debt sustainability in 11 Russian regions: A study based on hierarchical cluster analysis',
  'Moderate growth of government debt sustainability in 11 Russian regions: A case study based on hierarchical cluster analysis',
  'Moderate growth of government borrowing and debt sustainability: An application of Euclidean distance budget constraints and cluster analysis'],
 ['Sustainability in the food delivery sector: Empirical evidence from Deliveroo',
  'Sustainability in the food delivery sector: Enabling factors and obstacles to dissemination',
  'Sustainability in the food delivery sector: Empirical evidence from Deliveroo'],
 ['Sustainability in the logistics service sector: A content analysis of the top 50 global 3-PL companies',
  'Sustainability in the logistics service sector: A content analysis of mission statements of top 50 global 3-PL companies',
  'Sustainability in the logistics service sector: A content analysis of the top 50 global 3-PL companies'],
 ['Fiscal sustainability and feedback effects: A case study of Italy',
  'Fiscal sustainability and feedback effects: A model',
  'Long-term fiscal sustainability: A model incorporating feedback effects'],
 ['China’s water-energy-food system and its sustainable development: A system dynamics approach',
  '“Two-child” policy, trade friction, and water-energy-food system for China’s sustainable development: A system dynamics approach',
  'China’s water-energy-food system and sustainable development: A two-child policy and trade friction'],
 ['A ‘cradle-to-grave’ assessment of the sustainable development of microalgal biotechnology in coastal zones: A case study of the Maldives',
  'A ‘cradle-to-grave’ assessment of the sustainability of microalgal biotechnology in coastal zones: A case study of the Galápagos Islands',
  'A ‘cradle-to-grave’ assessment of the sustainable development of microalgal biotechnology in coastal zones: A case study of the Galápagos Islands'],
 ['Sustainable development of rural areas in the republic of Komi',
  'Sustainable development of rural areas in the republic of Komi [Устойчивость сталого развития российских регии]',
  'Sustainable development of rural settlements in the republic of Komi'],
 ['Synthetic indicator for debt sustainability analysis using dynamic general equilibrium models',
  'Synthetic indicator for debt sustainability analysis using dynamic general equilibrium models',
  'Synthetic indicator for debt sustainability analysis using dynamic general equilibrium models'],
 ['Managers’ views of corporate sustainability: A qualitative study of the Australian forestry and wood products industry',
  'Corporate sustainability logics and managers’ views: Evidence from the Australian forestry and wood products industry',
  'Managers’ views on corporate sustainability: A qualitative study of senior managers’ orientations'],
 ['Bioequivalence of multisource medications in Latin America: Implications for the sustainability of healthcare systems',
  'Bioequivalence of multisource medications in Latin America: Implications for cost-containment and sustainability',
  'Bioequivalence of generic and biosimilar medication in Latin America: Implications for cost-containment and sustainability'],
 ['The role of organizational capabilities in the sustainable development of the Italian wine industry: A dynamic resource-based perspective',
  'The role of organizational capabilities for implementing proactive socio-environmental practices and sustainable development in the Italian wine industry: A dynamic resource-based perspective',
  'Exploring the role of organizational capabilities for implementing proactive socio-environmental practices and sustainable development in the Italian wine industry: A structural equation model'],
 ['The Bay of Brest and the sustainable development goals: A 50-year study of the changing dynamics of the bay of brest ecosystem',
  'Harnessing interdisciplinary knowledge for the Bay of Brest ecosystem: Implications for the sustainable development goals',
  'Sustainability of the Bay of Brest ecosystem over 50 years: An interdisciplinary research agenda'],
 ['Banking sector development during the covid-19 pandemic: A case study of Turkey',
  'Sustainability of the banking sector in Turkey during the covid-19 pandemic',
  'Sustainability of the banking sector in Turkey during the covid-19 pandemic'],
 ['Nano-bubbles and sustainability: A review and perspectives',
  'Nano-bubbles for boosting sustainability: A review and future directions',
  'Nano-bubbles and sustainability: A review and perspectives'],
 ['Collaborative development of a sustainability reporting tool for local governments',
  'Collaborative development of a sustainability reporting tool for local governments',
  'Collaborative development of a sustainability reporting tool for local governments'],
 ['Assessing the sustainability of the agroecosystem in a semi-arid Mediterranean village: A sociometabolic perspective',
  'Assessing the sustainability of the agroecosystem in a semi-arid Mediterranean village',
  'Assessing the sustainability of an agroecosystem in a semi-arid Mediterranean village'],
 ['Sustainability assessment in higher education institutions: A special issue',
  'Sustainability assessment in higher education institutions: A special issue',
  'Sustainability assessment in higher education institutions: A special issue'],
 ['Green chemistry, systems thinking, and social sustainability: Challenges and opportunities',
  'Green chemistry and systems thinking for balanced sustainability: A review',
  'Green chemistry and systems thinking for balanced sustainability: A review and challenges'],
 ['Optimizing corporate efficiency and environmental sustainability through the use of a DEA model in global logistics',
  'Sustainability and operational performance of global logistics companies: A DEA approach',
  'Improving operational performance and environmental sustainability in the logistics industry: A DEA-Grey forecasting approach'],
 ['Mapping sustainability initiatives in Latin American higher education institutions: The case of Mexico',
  'Mapping sustainability initiatives in Latin American higher education institutions: An empirical study',
  'Mapping sustainability initiatives in Latin American higher education institutions: The case of the Instituto Nacional de Educación Española'],
 ['Blue growth and sustainable development: A special issue',
  'Blue growth and sustainable development: A special issue on the topic',
  'Blue growth and sustainable development: A special issue'],
 ['Sustainability of a nano-sized blimp with duty-cycling high power actuators',
  'Sustainability of a nano-sized blimp with duty-cycling high power actuators and solar panels',
  'Sustainability of a nano-sized blimp using duty-cycling actuators'],
 ['The gap between knowledge and the object of knowledge: A problem of sustainable development and childhood education',
  'The gap between knowledge and the object of knowledge in the context of sustainable development and childhood',
  'Sustainable development and childhood: A problem of knowledge gaps and knowledge production'],
 ['Sustainability of peasant-farming systems in the Nicaraguan highlands: A case study of farmer field schools in the Nicaragua region',
  'Long-term impact of farmer field schools on the sustainability and food security of peasant-farming systems in the Nicaraguan highlands',
  'Sustainability of the peasant-farming system in the highlands of Nicaragua: Evaluating the impact of farmer field schools'],
 ['Using sound as an interactive medium for the sustainable development of traditional culture: The case of guqin culture',
  'Sustainable development of Guqin culture: Using sound as an interactive medium',
  'Sustainable development of traditional culture through the use of sound: The case of guqin culture'],
 ['Development and evaluation of Sustainable Development Goals indicators for local governments in Gyeonggi Province, South Korea from the perspective of glocal\xa0mainstreaming of sustainable development goals',
  'Development and evaluation of Sustainable Development Goals indicators for local governments in Gyeonggi Province, South Korea from the perspective of glocal\xa0mainstreaming of sustainable development goals and localization',
  'Development and evaluation of Sustainable Development Goals indicators for local governments in Gyeonggi Province, South Korea from the perspective of glocal\xa0mainstreaming of sustainable development goals'],
 ['Urban Agriculture and the Urban Ecosystem: A Pathway to Sustainability?',
  'Urban Agriculture and the Urban Ecosystem: An Alternative for Sustainability',
  'Urban Agriculture as a Mechanism for the Sustainable Development of the Urban Ecosystem'],
 ['Pinduoduo: A new e-commerce platform for sustainable development in China',
  'Pinduoduo: A Pathway to Sustainability in China’s E-Commerce Market',
  'Pinduoduo: A Chinese e-commerce platform for sustainable development in small cities'],
 ['Dynamic change of platform provider role for successful platform operation via the lens of platform business models: A case study of Pinduoduo',
  "Dynamic change of platform provider's role for successful platform operation via the lens of platform business models: A case study of Pinduoduo",
  'Dynamic change of platform business model and its impact on sustainable development: A case study of Pinduoduo in China'],
 ['The kindergarten teacher as an agency mobiliser for sustainability: The role of the child in play',
  'The kindergarten teacher as an agency mobiliser for sustainability',
  'The kindergarten teacher as an agency mobiliser for sustainability'],
 ['Multi-criteria assessment of the multifunctional effects of different farming methods on sustainability and social well-being: A case study of a Mediterranean farming system',
  'Multi-criteria assessment of the multifunctional effects of different farming methods on the sustainability of different cultivation systems',
  'Multi-criteria assessment of the multifunctional effects of different farming methods on the sustainability of organic and conventional systems'],
 ["Evaluating the implementation of the Redesigned Community Health Fundprogram in the Dodoma region of Tanzania: a process evaluation protocol to open the 'black box' of micro health insurance in sub-Saharan Africa",
  'Process evaluation of the Redesigned Community Health Fundprogram in the Dodoma region of Tanzania: A step towards sustainable development goals',
  "Open the 'black box' to evaluate the implementation processes of the Redesigned Community Health Fundprogram in the Dodoma region of Tanzania: Implications for sustainability"],
 ['Sustainability differentiation in the Swiss fish trade and sales business',
  'Sustainability differentiation of fish in Switzerland: The role of state intervention and product differentiation',
  'Sustainability differentiation in the Swiss fish trade and sales business'],
 ['Financial sustainability of stingless bee farming in Malaysia: An appraisal of future growth projections',
  'Financial sustainability and future growth projections of stingless bee farming: A case study in Malaysia',
  'Financial projections and future sustainability of stingless bee farming: A case study in Malaysia'],
 ['Space debris and sustainable development: A review',
  'Sustainability of satellite technology in the era of space debris',
  'Space debris: A challenge for sustainable development in space'],
 ['Financial and economic feasibility of biogas production for sustainable development in rural households and villages in South Africa',
  'Financial and economic sustainability of biogas production for rural households and villages in the Eastern Cape, South Africa',
  'Financial and economic feasibility of biogas production to meet household or village energy needs in the Eastern Cape, South Africa'],
 ['EnergySavers: Achieving "bridge sustainability" for low-income households through energy efficiency behaviour change',
  'EnergySavers: A pathway to sustainability for low-income households in Australia',
  'EnergySavers: An Australian low-income household energy behaviour change program to improve sustainability outcomes'],
 ['Environmental sustainability assessment of reusable textile masks during the covid-19 pandemic',
  'Environmental sustainability of reusable textile facemasks during the covid-19 pandemic: A life cycle assessment',
  'Environmental sustainability of reusable textile masks in the COVID-19 pandemic'],
 ['Organizational characteristics and the availability of nicotine replacement therapy in substance use disorder treatment programs: A longitudinal study',
  'Sustainability of smoking cessation services in substance use disorders treatment programs: A longitudinal analysis of the organizational characteristics associated with the availability of nicotine replacement therapy',
  'Organizational characteristics and the availability of nicotine replacement therapy in substance use disorder treatment programs: A longitudinal analysis of the role of organizational covariates'],
 ['Sustainable Resilient Strategic Decision-Support: A New Approach to Strategic Sustainability and Resilience',
  'Sustainable Resilient Strategic Decision-Support: A new approach to strategic sustainability and resilience',
  'Sustainable Resilient Strategic Decision-Support: A New Approach to Strategic Sustainability and Resilience'],
 ['Energy sustainability assessment of electricity generation systems using super-efficiency data envelopment analysis',
  'Energy sustainability assessment using super-efficiency data envelopment analysis',
  'A sustainability assessment index system for electricity generation systems: A review and proposal'],
 ['Sustainability of taxi efficiency by reducing the size of taxis in Hangzhou',
  'Sustainability of taxi efficiency using hatchback cars: A case study in Hangzhou, China',
  'Taxi efficiency and sustainability: A new approach to taxi efficiency using hatchback cars'],
 ['Evaluation of the spatial data quality of OpenStreetMap for monitoring sustainable development goalsindicators',
  'Evaluation of spatial data quality elements of OpenStreetMap for monitoring sustainable development goals',
  'Evaluation of the spatial data quality of OpenStreetMap for monitoring sustainable development indicators'],
 ["Super-slack-based measure of China's sustainable development efficiency based on the driver-pressure-state-impact-response framework: A three-stage data envelope analysis",
  "Sustainable development efficiency of China's provinces and cities: A super-slack-based measure using data envelope analysis",
  "Super-slack-based measure of China's sustainable development efficiency using a three-stage data envelope analysis approach"]]

bart_sen =  [item[0] for item in bart]
bart_lower_sen = [x.lower() for x in bart_sen]
bart_tok_sen = [word_tokenize(i) for i in bart_lower_sen] 

original = ['Food security and sustainability: Exploring Japanese youth participation in agriculture',
'Canada\'s oil sands industry from a sustainability perspective',
'Perspectives on sustainability in humanitarian supply chains',
'Student Learning on Sustainable Development Goals through Interactive Lectures and Fieldwork in Rural Communities: Grounded Theory Approach',
'Innovation: A modering factor the effectiveness of diversification strategies on the sustainability of hospital farms',
'Building A Comprehensive Conceptual Framework for Material Selection in Terms of Sustainability in The Construction Preliminary Design Phase',
'A study of quality assessment in higher education within the context of sustainable development: A case study from Czech Republic',
'Towards sustainability in the port sector: The role of intermediation in transition work',
'Events and sustainability: why making events more sustainable is not enough',
'Local and distributed manufacturing during the COVID-19 pandemic: Is crisis a window of opportunity for sustainable development in the Global South?',
'Efficiency and sustainability analysis of the repair and maintenance operations of uns m11917 magnesium alloy parts of the aeronautical industry made by intermittent facing',
'Association rule mining tourist-attractive destinations for the sustainable development of a large tourism area in Hokkaido using Wi-Fi tracking data',
'Using the Flipped Classroom to Promote Learner Engagement for the Sustainable Development of Language Skills: A Mixed-Methods Study',
'Social leveraging of the 2010 Olympic Games: sustainability in a City of Vancouver initiative',
'Nature of the wind, the culture of the landscape: Toward an energy sustainability project in catalonia',
'Universities as potential actors for sustainable development',
'Applying carbon footprint method possibilities to the sustainable development of sports tourism',
'Effects of taxation on social innovation and implications for achieving sustainable development goals in developing countries: A literature review',
'Reprocessed Materials Used in Rotationally Moulded Sandwich Structures for Enhancing Environmental Sustainability: Low-Velocity Impact and Flexure-after-Impact Responses',
'Assessing the degree of sustainability integration in Canadian public sector procurement',
'Livestock breeding for sustainability to mitigate global warming, with the emphasis on developing countries',
'Enterprise location choice and regional sustainable development based on the theory of stable matching',
'Monitoring of efficiency of Russian agricultural enterprises functioning and reserves for their sustainable development',
'Modifications to ART service delivery models by health facilities in Uganda in promotion of intervention sustainability: A mixed methods study',
'Increasing the sustainability of alkali-activated binders: The use of sugar cane straw ash',
'Digitalization: The Engine of Sustainability in the Energy Industry',
'Drivers for universities: contribution to the sustainable development goals: An analysis of Spanish public universities',
'US biopharmaceutical companies\' stock market reaction to the COVID-19 pandemic. Understanding the concept of the paradoxical spiral from a sustainability perspective',
'The contemporary illusion: population growth and sustainability',
'Sustainability claim, environmental misconduct and perceived hypocrisy in luxury branding',
'Migration and justice in the era of sustainable development goals: a conceptual framework',
'An Empirical Analysis of Russian Regions: Debt Sustainability',
'Contribution to the sustainability challenges of the food-delivery sector: Finding from the deliveroo italy case study',
'Using publicized information to determine the sustainable development of 3-PL companies',
'Debt projections and fiscal sustainability with feedback effects',
'A study on the sustainable development of water, energy, and food in China',
'Sustainable development of microalgal biotechnology in coastal zone for aquaculture and food',
'Problems and social policy priorities sustainable development of rural territories',
'Public debt frontier: A python toolkit for analyzing public debt sustainability',
'Can business-oriented managers be effective leaders for corporate sustainability? A study of integrative and instrumental logics',
'The pharmaceutical industry and the sustainability of healthcare systems in developed countries and in Latin America',
'The role of organizational capabilities in attaining corporate sustainability practices and economic performance: Evidence from Italian wine industry',
'The impossible sustainability of the bay of brest? Fifty years of ecosystem changes, interdisciplinary knowledge construction and key questions at the science-policy-community interface',
'The impact of the COVID-19 pandemic outbreak on the sustainable development of the Turkish banking sector',
'Environmental Exploration of Ultra-Dense Nanobubbles: Rethinking Sustainability',
'Sustainability reporting: An approach to get the right mix of theory and practicality for local actors',
'Belowground and Aboveground Sustainability: Historical Management Change in a Mediterranean Agroecosystem',
'Sustainability assessment in higher education institutions',
'Socio-problematization of green chemistry: Enriching systems thinking and social sustainability by education',
'A grey forecasting approach for the sustainability performance of logistics companies',
'Mapping sustainability initiatives in higher education institutions in Latin America',
'What is blue growth? The semantics of â€œSustainable Developmentâ€ of marine environments',
'Self-sustainability in nano unmanned aerial vehicles: A blimp case study',
'Needle and Stick save the world: Sustainable development and the universal child',
'Farmer field schools: A tool empowering sustainability and food security in peasant farming systems in the nicaraguan highlands',
'Sound Design of Guqin Culture: Interactive Art Promotes the Sustainable Development of Traditional Culture',
'Developing an index of sustainable development goals for local governments: the case of Gyeonggi province in korea',
'Agriculture in urban ecosystems: A step to cities sustainability',
'E-commerce sustainability: The case of Pinduoduo in China',
'How to maintain the sustainable development of a business platform: A case study of Pinduoduo Social Commerce Platform in China',
'Becoming child and sustainability: the kindergarten teacher as agency mobiliser for sustainability through keeping the concept of the child in play',
'Assessment of the sustainability of wild rocketproduction: Application of a multi-criteria method to different farming systems in the province of Udine',
'Factors affecting adoption, implementation fidelity, and sustainability of the Redesigned Community Health Fund in Tanzania: A mixed methods protocol for process evaluation in the Dodoma region',
'Drawing the line between sustainable and unsustainable fish: product differentiation that supports sustainable development through trade measures',
'The Application of Risk Analysis To The Project Appraisal Of Stingless Bee Farming In Malaysia For Sustainability',
'Orbital Debris Threat for Space Sustainability and Way Forward',
'Financial and economic feasibility of bio-digesters for rural residential demand-side management and sustainable development',
'Increasing energy-saving actions in low income households to achieve sustainability',
'Cotton and surgical masks: what ecological factors are relevant for their sustainability?',
'Availability of nicotine replacement therapy in substance use disorder treatment: Longitudinal patterns of adoption, sustainability, and discontinuation',
'Putting resilient sustainability into strategy decisions case studies',
'A comparison of electricity generation system sustainability among G20 countries',
'Taxi downsizing: A new approach to efficiency and sustainability in the taxi industry',
'Analysis of OpenStreetMap Data Quality for Selected Counties in Poland in Terms of Sustainable Development',
'Analysis of scale factors on China\'s sustainable development efficiency based on three-stage DEA and a double threshold test']

original_lower_sen = [x.lower() for x in original]
original_tok_sen = [word_tokenize(i) for i in original_lower_sen]

# %%
embedding1 = model.encode(bart_lower_sen, convert_to_tensor=True)
embedding2 = model.encode(original_lower_sen, convert_to_tensor=True)

# %%
# compute similarity scores of two embeddings
cosine_scores = util.pytorch_cos_sim(embedding1, embedding2)
scores=[]
for i in range(len(bart_lower_sen)):
        scores.append(cosine_scores[i][i].item())

# %%
##After this we take average of the scores, need to check with prof about the average thing
sim = sum(scores) / len(scores)

sim
# Out:
# 0.6980543843905131

# %%
## Bleu
# reference = [['Bert', 'Google'], ['Bloom', 'AI']]

score = []

for i in range(len(t5_sen)):
    hypothesis = t5_tok_sen[i]
    reference = original_tok_sen[i]
    score.append(sentence_bleu([reference], hypothesis, weights=(0.5, 0.5, 0, 0)))

score
# Out:
# [0.23362801673857259,
#  0.20412414523193154,
#  0.1507556722888818,
#  0.39949970082700503,
#  1.6266250338817998e-155,
#  0.37329381614353174,
#  4.836051895127463e-155,
#  0.3380617018914066,
#  0.26167102380212115,
#  0.10208599557217783,
#  0.0905656578288731,
#  0.20461823568473816,
#  7.702941184607866e-155,
#  9.94445430826712e-155,
#  0.19296155547316018,
#  5.637975647982813e-155,
#  0.30151134457776363,
#  0.21892179513396468,
#  0.19867760554227556,
#  0.4208770096808336,
#  0.12126781251816653,
#  0.20232565955562798,
#  0.15430334996209186,
#  0.14934041489705524,
#  0.4688072309384954,
#  0.29957234475763905,
#  0.17320508075688773,
#  0.1402352690232509,
#  6.17087516772532e-155,
#  0.1507556722888818,
#  0.223606797749979,
#  0.3279715789102868,
#  2.8908557358588537e-155,
#  4.268180403672974e-155,
#  0.26967994498529685,
#  0.15432215303129293,
#  7.031791076575252e-155,
#  0.36514837167011077,
#  0.1740776559556978,
#  0.18132731507474048,
# ...

# %%
similarity = sum(score) / len(score)

# %%
similarity
# Out:
# 0.18675067688481797

# %%
rouge = Rouge()

for i in range(len(t5_sen)):
  sc = rouge.get_scores(t5_lower_sen[i], original_lower_sen[i], avg=True)

sc
# Out:
# {'rouge-1': {'r': 0.17647058823529413, 'p': 0.25, 'f': 0.20689654687277062},
#  'rouge-2': {'r': 0.058823529411764705,
#   'p': 0.08333333333333333,
#   'f': 0.06896551239001224},
#  'rouge-l': {'r': 0.17647058823529413, 'p': 0.25, 'f': 0.20689654687277062}}

# %%
## Rouge ##Not sure if it works for keywords, these metrics were originally made to compare sequences.
rouge = Rouge()

for i in range(len(bart_sen)):
  sc = rouge.get_scores(bart_lower_sen[i], original_lower_sen[i], avg=True)

sc
# Out:
# {'rouge-1': {'r': 0.5882352941176471,
#   'p': 0.5882352941176471,
#   'f': 0.5882352891176471},
#  'rouge-2': {'r': 0.29411764705882354, 'p': 0.3125, 'f': 0.30303029803489445},
#  'rouge-l': {'r': 0.47058823529411764,
#   'p': 0.47058823529411764,
#   'f': 0.47058823029411767}}

# %%
## Combination of Rouge and Bleu
F1 = 2 * (score * 0.23) / (score + 0.23)

# %%
F1
# Out:
# 2.1601350937751257e-231

# %%
##Sematch ## Wordnet similarity ##WUP Similarity & RES Similarity 
## First, WUP similarity or Leacock&Chodorow, these measure semantic similarity based on shortest path distance, Least common subsumers
## Secondly, Resnik, information content of the least common subsumer. 
## Doesn't work with Python 2.7+, will use this on pycharm instead. 
import nltk                                                                                 
import gensim                                                                               
from gensim.parsing.preprocessing import remove_stopwords                                   
from nltk.corpus import stopwords                                                           
from nltk.tokenize import word_tokenize                                                     
from sematch.semantic.similarity import WordNetSimilarity                                   
                                                                                            
nltk.download('wordnet_ic')                                                                 
nltk.download('stopwords')                                                                  
wns = WordNetSimilarity()                                                                   
                                                                                            
# res - information content, wup- path length to subsumer, there are others I will explore  
# wup gives under 1 score, res gives over 1 score. Need to check this.                      
# print(wns.word_similarity('dog', 'cat', 'li'))                                            
# print(wns.word_similarity('dog', 'cat', 'wup'))                                           
# print(wns.word_similarity('dog', 'cat', 'res'))                                           
                                                                                            
                                                                                            
## Code from here                                                                           
                                                                                            
sc = []                                                                                     
fil_sen = []                                                                                
sen = ['water should be a priority', 'land is fertile']                                     
for i in range(len(sen)):                                                                   
    fil_sen.append(remove_stopwords(sen[i]))                                                
                                                                                            
tok_sen = [word_tokenize(i) for i in fil_sen]                                               
                                                                                            
# tok_sen = [['water', 'priority'], ['land', 'fertile']]                                    
keywords = [['sustainability', 'water'], ['land', 'fertile']]                               
                                                                                            
## Compare the lists here                                                                   
for i in range(len(tok_sen)):                                                               
    temp_sen = tok_sen[i]                                                                   
    temp_keys = keywords[i]                                                                 
    print(temp_keys)                                                                        
    for k in range(len(temp_sen)):                                                          
        for m in range(len(temp_keys)):                                                     
            sc.append(wns.word_similarity(temp_sen[k], temp_keys[m], 'wup'))                
                                                                                            
print(sc)                                                                                   
                                                                                            
similarity = sum(sc) / len(sc)                                                              
                                                                                            
print(similarity)

# %%
## Statistical based similarity (I'm using Word2vec and Fasttext to find semantic similarity between sentences)
## Both use cosine similarity 
## Word2Vec takes texts as training data for a neural network. The resulting embedding captures whether words appear in similar contexts. 
## GloVe focuses on words co-occurrences over the whole corpus. Its embeddings relate to the probabilities that two words appear together.
## FastText operates at a more granular level with character n-grams. Where words are represented by the sum of the character n-gram vectors.
## Fasttext uses the cosine of the angles between two vectors. This similarity is computed for all words in the vocabulary, and the 10 most similar words are shown.
## Glove conversion to Word2Vec is causing issues. 

## Word2vec

# load w2v from pre-built Google data
# download bin.gz from: https://code.google.com/archive/p/word2vec/
## Running this on PyCharm
w2v = KeyedVectors.load_word2vec_format("./data/GoogleNews-vectors-negative300.bin", binary=True)

w2v_vocab = set(w2v.index_to_key)

## Question: Do I remove or keep stopwords, ask professor
sentences = ["I am happy to shop in Walmart and buy a Google phone",
             "In today's demo we'll look at Office and Word from microsoft"]

target_sentences = [["Google", "Walmart"], ["Office", "Microsoft"]]

# sentences_similarity = np.zeros(len(sentences))

sentence_words = []
sim = []

for idx, sentence in enumerate(sentences):
    sentence_words.append([w for w in sentence.split() if w in w2v_vocab])

for i in range(len(sentences)):
    sim.append(w2v.n_similarity(target_sentences[i], sentence_words[i]))

similarity = sum(sim) / len(sim)

print(similarity)


## Glove ## Still left to do
## Converting glove format to word2vec format

# glove_file = datapath("glove.840B.300d.txt")
# tmp_file = get_tmpfile("glove_to_word2vec.txt")
# storing = glove2word2vec(glove_file, tmp_file)
#
# g2v = KeyedVectors.load_word2vec_format(tmp_file, binary=False, encoding='unicode_escape')
#
# g2v_vocab = set(g2v.index_to_key)

##2nd method
glove2word2vec(glove_input_file="glove.840B.300d.txt", word2vec_output_file="gensim_glove_vectors.txt")

glove_model = KeyedVectors.load_word2vec_format("gensim_glove_vectors.txt", binary=False)
## EOFError: unexpected end of input; is count incorrect or file otherwise damaged?
## Conversion is creating a lot of problems

# ## Question: Do I remove or keep stopwords, ask professor
# sentences = ["I am happy to shop in Walmart and buy a Google phone",
#              "In today's demo we'll look at Office and Word from microsoft"]

# target_sentences = [["Google", "Asda"], ["Office", "Microsoft"]]
#
# sentences_similarity = np.zeros(len(sentences))
#
# sentence_words = []
# sim = []
#
# for idx, sentence in enumerate(sentences):
#     sentence_words.append([w for w in sentence.split() if w in g2v_vocab])
#
# for i in range(len(sentences)):
#     sim.append(g2v.n_similarity(target_sentences[i], sentence_words[i]))
#
# similarity = sum(sim) / len(sim)
#
# print(similarity)


## FastText
## Running this on PyCharm
w2v = KeyedVectors.load_word2vec_format("./data/crawl-300d-2M.vec", binary=False)

w2v_vocab = set(w2v.index_to_key)

# Question: Do I remove or keep stopwords, ask professor
sentences = ["I am happy to shop in Walmart and buy a Google phone",
             "In today's demo we'll look at Office and Word from microsoft"]

target_sentences = [["Google", "Walmart"], ["Office", "Microsoft"]]

# sentences_similarity = np.zeros(len(sentences))

sentence_words = []
sim = []

for idx, sentence in enumerate(sentences):
    sentence_words.append([w for w in sentence.split() if w in w2v_vocab])

for i in range(len(sentences)):
    sim.append(w2v.n_similarity(target_sentences[i], sentence_words[i]))

similarity = sum(sim) / len(sim)

print(similarity)
